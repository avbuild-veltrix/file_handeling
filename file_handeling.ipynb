# %%
file = open("file.txt", "w")

# %%
file.write("This is my first line")
# Out:
# 21

# %%
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line")
file.write("This is my second line")
file.write("This is my third line")
file.write("This is my fourth line")
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line")
# Out:
# 21

# %%
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line")
# Out:
# 21

# %%
file.close()

# %%
file = open("file.txt", "a")
file.write("\nThis is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
for i in file:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for i in file:
#       2     print(i)
#
# ValueError: I/O operation on closed file.

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='a' encoding='cp1252'>

# %%
file = open("file.txt", "r")
for i in file:
    print(i)
# Out:
# This is my first line
#
# This is my first line
#
# This is my second line
#
# This is my third line
#
# This is my fourth line

# %%
print(file.read())

# %%
file.close()

# %%
file = open("file.txt", "r")

# %%
print(file.read())
# Out:
# This is my first line
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line

# %%
file = open("file.txt", "r")
file.read()
# Out:
# 'This is my first line\nThis is my first line\nThis is my second line\nThis is my third line\nThis is my fourth line\n'

# %%
file.tell()
# Out:
# 117

# %%
file.seek(0)
# Out:
# 0

# %%
file.tell()
# Out:
# 0

# %%
print(file.readline())
# Out:
# This is my first line

# %%
print(file.readlines())
# Out:
# ['This is my first line\n', 'This is my second line\n', 'This is my third line\n', 'This is my fourth line\n']

# %%
#Present working directory
# !pwd
# Out:
# /c/Users/karti/Data Science/2. File handling

# %%
#To make file, folder in the directory
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karti\\Data Science\\2. File handling'

# %%
os.path.getsize("file.txt")
# Out:
# 117

# %%
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
os.makedirs("1/2/3/4")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 os.makedirs("1/2/3/4")
#
# File <frozen os>:228, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: '1/2/3/4'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 90C6-01AA
#
#  Directory of C:\Users\karti\Data Science\2. File handling
#
# 24-06-2026  17:40    <DIR>          .
# 21-06-2026  12:05    <DIR>          ..
# 23-06-2026  19:52    <DIR>          .ipynb_checkpoints
# 24-06-2026  17:36    <DIR>          1
# 24-06-2026  17:39    <DIR>          2
# 24-06-2026  17:40               117 file.txt
# 24-06-2026  17:39            23,579 file_handeling.ipynb
# 23-06-2026  19:49            19,126 File_handeling_basics.ipynb
# 24-06-2026  17:40    <DIR>          test
#                3 File(s)         42,822 bytes
#                6 Dir(s)  82,424,692,736 bytes free

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1',
#  '2',
#  'file.txt',
#  'file_handeling.ipynb',
#  'File_handeling_basics.ipynb',
#  'test']

# %%
os.mkdir("feat")

# %%
os.rmdir("feat")

# %%
os.rmdir("test")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 os.rmdir("test")
#
# OSError: [WinError 145] The directory is not empty: 'test'

# %%
import shutil

# %%
shutil.rmtree("test")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karti\\Data Science\\2. File handling'

# %%
f = open("1/2/3/4/file.txt","w")

# %%
os.mkdir("2")

# %%
shutil.copy("C:/Users/karti/Data Science/2. File handling/1/2/3/4/file.txt","C:/Users/karti/Data Science/2. File handling/1/2")
# Out:
# 'C:/Users/karti/Data Science/2. File handling/1/2\\file.txt'

# %%
shutil.move("C:/Users/karti/Data Science/2. File handling/1/2/3/file.txt","C:/Users/karti/Data Science/2. File handling/2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/karti/Data Science/2. File handling/1/2/3/file.txt' -> 'C:/Users/karti/Data Science/2. File handling/2\\file.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 shutil.move("C:/Users/karti/Data Science/2. File handling/1/2/3/file.txt","C:/Users/karti/Data Science/2. File handling/2")
#
# File ~\anaconda3\Lib\shutil.py:876, in move(src, dst, copy_function)
#     874         rmtree(src)
#     875     else:
# --> 876         copy_function(src, real_dst)
# ...

# %%
os.mkdir("file_test")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karti\\Data Science\\2. File handling'

# %%
shutil.move("C:/Users/karti/Data Science/2. File handling/1/file.txt","C:/Users/karti/Data Science/2. File handling/file_test")
# Out:
# 'C:/Users/karti/Data Science/2. File handling/file_test\\file.txt'

# %%
file1 = open("file1.txt","w")

# %%
#Reading the content of the file without closing it>> WITH Statement>> With statement ensures that the file is closed properly after exeecution of the block of the code
with open("file1.txt","w") as f:
    f.write("This is my first line")
